# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %%
abbr = 'OR'

# %%
file = 'oregon.xlsx'

# %% [markdown]
# Read in federal level data

# %%
fiscal = pd.read_sas('../../data/fiscal2018', format = 'sas7bdat', encoding='iso-8859-1')

# %% [markdown]
# Generate list of districts in the state in the federal data

# %%
state_fiscal = fiscal[(fiscal['STABBR'] == abbr) & (fiscal['GSHI'] == '12')]

# %%
len(state_fiscal)
# Out:
# 209

# %% [markdown]
# Read in state level data

# %%
state_grads = pd.read_excel('../../data/state_data_raw/' + file, sheet_name='Four-year Cohort Data')

# %%
state_grads
# Out:
#       2017-18 Four-year Cohort Graduation Rates\nStudents first enrolled in High School in 2014-15  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                 County
# 3                                        State of Oregon
# 4                                        State of Oregon
# ...                                                  ...
# 14595                                            Yamhill
# 14596                                            Yamhill
# 14597                                            Yamhill
# 14598                                            Yamhill
# 14599                                            Yamhill
#
#         Unnamed: 1       Unnamed: 2 Unnamed: 3       Unnamed: 4  \
# 0              NaN              NaN        NaN              NaN
# 1              NaN              NaN        NaN              NaN
# 2      District ID    District Name  School ID      School Name
# 3             9999  State of Oregon       9999  State of Oregon
# 4             9999  State of Oregon       9999  State of Oregon
# ...            ...              ...        ...              ...
# 14595            0  State of Oregon          0   Yamhill County
# 14596            0  State of Oregon          0   Yamhill County
# 14597            0  State of Oregon          0   Yamhill County
# 14598            0  State of Oregon          0   Yamhill County
# 14599            0  State of Oregon          0   Yamhill County
#
#                Unnamed: 5              Unnamed: 6         Unnamed: 7  \
# 0                     NaN                     NaN                NaN
# 1                     NaN                     NaN                NaN
# 2      Student Group Code           Student Group  Unadjusted Cohort
# 3                     Tot            All Students              51049
# 4                       M                    Male              26145
# ...                   ...                     ...                ...
# 14595               Mgrnt                 Migrant                 48
# 14596               Hmlss       Homeless Students                 92
# 14597                CDIS  Combined Disadvantaged               1200
# 14598           CTEPartic        CTE Participants               1124
# 14599             CTEConc       CTE Concentrators                611
#
#                                               Unnamed: 8 Unnamed: 9  ...  \
# 0                                                    NaN        NaN  ...
# 1                                Removed from the Cohort        NaN  ...
# 2      Transfer Out to Another State, Country, Privat...   Deceased  ...
# 3                                                   4908         60  ...
# 4                                                   2417         33  ...
# ...                                                  ...        ...  ...
# 14595                                                  1          0  ...
# 14596                                                 10          0  ...
# 14597                                                 70          0  ...
# 14598                                                 41          0  ...
# 14599                                                 11          0  ...
#
#                                     Unnamed: 14                Unnamed: 15  \
# 0                                           NaN              Non-Graduates
# 1                                           NaN           Other Completers
# 2      2017-18 Four-year Cohort Graduation Rate  Adult High School Diploma
# 3                                         78.68                          1
# 4                                         75.55                          1
# ...                                         ...                        ...
# 14595                                     80.85                          0
# 14596                                     68.29                          0
# 14597                                     85.04                          0
# 14598                                     92.15                          0
# 14599                                     95.83                          0
#
#             Unnamed: 16 Unnamed: 17                              Unnamed: 18  \
# 0                   NaN         NaN                                      NaN
# 1                   NaN         NaN                                      NaN
# 2      Extended Diploma         GED  2017-18 Four-year Cohort Completer Rate
# 3                   153        1621                                    82.53
# 4                   104         948                                       80
# ...                 ...         ...                                      ...
# 14595                 0           1                                    82.98
# 14596                 0           3                                    71.95
# 14597                 4          20                                    87.17
# 14598                 4           8                                    93.26
# 14599                 2           3                                    96.67
#
#                    Unnamed: 19                       Unnamed: 20  \
# 0                          NaN                               NaN
# 1                          NaN                    Non-Completers
# 2      Alternative Certificate  Continuing Enrollment in 2018-19
# 3                          271                              2537
# 4                          176                              1467
# ...                        ...                               ...
# 14595                        0                                 2
# 14596                        1                                 6
# 14597                       18                                37
# 14598                       13                                22
# 14599                        1                                 4
#
#                 Unnamed: 21        Unnamed: 22  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2      Other Non-Completers  Institution Level
# 3                      5241        State Level
# 4                      3097        State Level
# ...                     ...                ...
# 14595                     6             County
# 14596                    16             County
# 14597                    90             County
# 14598                    38             County
# 14599                    15             County
#
#                                              Unnamed: 23
# 0                                                    NaN
# 1                                                    NaN
# 2      2016-17 (prior year) Four-year Cohort Graduati...
# 3                                                  76.65
# 4                                                  73.62
# ...                                                  ...
# 14595                                              85.19
# 14596                                              61.06
# 14597                                              81.43
# 14598                                              88.78
# 14599                                              92.14
#
# [14600 rows x 24 columns]

# %% [markdown]
# Reset columns.

# %%
state_grads.columns = state_grads.loc[2]
state_grads = state_grads.loc[3:]

# %%
state_grads
# Out:
# 2               County District ID    District Name School ID  \
# 3      State of Oregon        9999  State of Oregon      9999
# 4      State of Oregon        9999  State of Oregon      9999
# 5      State of Oregon        9999  State of Oregon      9999
# 6      State of Oregon        9999  State of Oregon      9999
# 7      State of Oregon        9999  State of Oregon      9999
# ...                ...         ...              ...       ...
# 14595          Yamhill           0  State of Oregon         0
# 14596          Yamhill           0  State of Oregon         0
# 14597          Yamhill           0  State of Oregon         0
# 14598          Yamhill           0  State of Oregon         0
# 14599          Yamhill           0  State of Oregon         0
#
# 2          School Name Student Group Code                  Student Group  \
# 3      State of Oregon                Tot                   All Students
# 4      State of Oregon                  M                           Male
# 5      State of Oregon                  F                         Female
# 6      State of Oregon                 AM  American Indian/Alaska Native
# 7      State of Oregon                ASO                          Asian
# ...                ...                ...                            ...
# 14595   Yamhill County              Mgrnt                        Migrant
# 14596   Yamhill County              Hmlss              Homeless Students
# 14597   Yamhill County               CDIS         Combined Disadvantaged
# 14598   Yamhill County          CTEPartic               CTE Participants
# 14599   Yamhill County            CTEConc              CTE Concentrators
#
# 2     Unadjusted Cohort  \
# 3                 51049
# 4                 26145
# 5                 24904
# 6                   836
# 7                  2241
# ...                 ...
# 14595                48
# 14596                92
# 14597              1200
# 14598              1124
# 14599               611
#
# 2     Transfer Out to Another State, Country, Private School, or Homeschool  \
# 3                                                   4908
# 4                                                   2417
# 5                                                   2491
# 6                                                     94
# 7                                                    293
# ...                                                  ...
# 14595                                                  1
# 14596                                                 10
# 14597                                                 70
# 14598                                                 41
# 14599                                                 11
#
# 2     Deceased  ... 2017-18 Four-year Cohort Graduation Rate  \
# 3           60  ...                                    78.68
# 4           33  ...                                    75.55
# 5           27  ...                                    81.99
# 6            2  ...                                    65.27
# 7            3  ...                                    90.59
# ...        ...  ...                                      ...
# 14595        0  ...                                    80.85
# 14596        0  ...                                    68.29
# 14597        0  ...                                    85.04
# 14598        0  ...                                    92.15
# 14599        0  ...                                    95.83
#
# 2     Adult High School Diploma Extended Diploma   GED  \
# 3                             1              153  1621
# 4                             1              104   948
# 5                             0               49   673
# 6                             0                5    39
# 7                             0                2    11
# ...                         ...              ...   ...
# 14595                         0                0     1
# 14596                         0                0     3
# 14597                         0                4    20
# 14598                         0                4     8
# 14599                         0                2     3
#
# 2     2017-18 Four-year Cohort Completer Rate Alternative Certificate  \
# 3                                       82.53                     271
# 4                                          80                     176
# 5                                       85.22                      95
# 6                                       71.22                       5
# 7                                       91.26                      13
# ...                                       ...                     ...
# 14595                                   82.98                       0
# 14596                                   71.95                       1
# 14597                                   87.17                      18
# 14598                                   93.26                      13
# 14599                                   96.67                       1
#
# 2     Continuing Enrollment in 2018-19 Other Non-Completers Institution Level  \
# 3                                 2537                 5241       State Level
# 4                                 1467                 3097       State Level
# 5                                 1070                 2144       State Level
# 6                                   75                  133       State Level
# 7                                   71                   86       State Level
# ...                                ...                  ...               ...
# 14595                                2                    6            County
# 14596                                6                   16            County
# 14597                               37                   90            County
# 14598                               22                   38            County
# 14599                                4                   15            County
#
# 2     2016-17 (prior year) Four-year Cohort Graduation Rate
# 3                                                  76.65
# 4                                                  73.62
# 5                                                  79.93
# 6                                                  59.13
# 7                                                  88.93
# ...                                                  ...
# 14595                                              85.19
# 14596                                              61.06
# 14597                                              81.43
# 14598                                              88.78
# 14599                                              92.14
#
# [14597 rows x 24 columns]

# %% [markdown]
# Filter results.

# %%
state_grads = state_grads[(state_grads['Institution Level'] == 'District') &
                         (state_grads['Student Group'] == 'All Students')]

# %%
state_grads
# Out:
# 2       County District ID           District Name School ID  \
# 30        Lake        2063              Adel SD 21      2063
# 82     Malheur        2113            Adrian SD 61      2113
# 134     Benton        1899             Alsea SD 7J      1899
# 186    Yamhill        2252             Amity SD 4J      2252
# 238    Malheur        2111             Annex SD 29      2111
# ...        ...         ...                     ...       ...
# 13264  Yamhill        2255        Willamina SD 30J      2255
# 13342  Douglas        2002  Winston-Dillard SD 116      2002
# 13472   Marion        2146         Woodburn SD 103      2146
# 13550  Yamhill        2251    Yamhill Carlton SD 1      2251
# 13602  Douglas        1997          Yoncalla SD 32      1997
#
# 2                 School Name Student Group Code Student Group  \
# 30                 Adel SD 21                Tot  All Students
# 82               Adrian SD 61                Tot  All Students
# 134               Alsea SD 7J                Tot  All Students
# 186               Amity SD 4J                Tot  All Students
# 238               Annex SD 29                Tot  All Students
# ...                       ...                ...           ...
# 13264        Willamina SD 30J                Tot  All Students
# 13342  Winston-Dillard SD 116                Tot  All Students
# 13472         Woodburn SD 103                Tot  All Students
# 13550    Yamhill Carlton SD 1                Tot  All Students
# 13602          Yoncalla SD 32                Tot  All Students
#
# 2     Unadjusted Cohort  \
# 30                    0
# 82                   41
# 134                  27
# 186                  83
# 238                  10
# ...                 ...
# 13264                78
# 13342               130
# 13472               367
# 13550                95
# 13602                49
#
# 2     Transfer Out to Another State, Country, Private School, or Homeschool  \
# 30                                                     0
# 82                                                    15
# 134                                                    1
# 186                                                    8
# 238                                                    9
# ...                                                  ...
# 13264                                                  1
# 13342                                                  2
# 13472                                                 24
# 13550                                                  9
# 13602                                                 10
#
# 2     Deceased  ... 2017-18 Four-year Cohort Graduation Rate  \
# 30           0  ...                                       --
# 82           0  ...                                    88.46
# 134          0  ...                                       50
# 186          0  ...                                    85.33
# 238          0  ...                                        0
# ...        ...  ...                                      ...
# 13264        0  ...                                    83.12
# 13342        0  ...                                    65.63
# 13472        0  ...                                    88.92
# 13550        0  ...                                    86.05
# 13602        0  ...                                    53.85
#
# 2     Adult High School Diploma Extended Diploma GED  \
# 30                            0                0   0
# 82                            0                0   0
# 134                           0                0   0
# 186                           0                0   0
# 238                           0                0   0
# ...                         ...              ...  ..
# 13264                         0                0   1
# 13342                         0                0   1
# 13472                         0                0   0
# 13550                         0                0   1
# 13602                         0                0   1
#
# 2     2017-18 Four-year Cohort Completer Rate Alternative Certificate  \
# 30                                         --                       0
# 82                                      88.46                       3
# 134                                        50                       0
# 186                                     85.33                       0
# 238                                         0                       0
# ...                                       ...                     ...
# 13264                                   84.42                       2
# 13342                                   66.41                       0
# 13472                                   88.92                       8
# 13550                                   87.21                       0
# 13602                                   56.41                       0
#
# 2     Continuing Enrollment in 2018-19 Other Non-Completers Institution Level  \
# 30                                   0                    0          District
# 82                                   0                    0          District
# 134                                  6                    7          District
# 186                                  3                    8          District
# 238                                  0                    1          District
# ...                                ...                  ...               ...
# 13264                                1                    9          District
# 13342                                3                   40          District
# 13472                                7                   23          District
# 13550                                3                    8          District
# 13602                                2                   15          District
#
# 2     2016-17 (prior year) Four-year Cohort Graduation Rate
# 30                                                    --
# 82                                                   100
# 134                                                92.31
# 186                                                74.39
# 238                                                   --
# ...                                                  ...
# 13264                                              69.35
# 13342                                              73.39
# 13472                                              88.92
# 13550                                              80.49
# 13602                                              66.67
#
# [197 rows x 24 columns]

# %% [markdown]
# Select and rename columns.

# %%
state_grads = state_grads[['District Name', 
                           'Adjusted Cohort', 
                           '2017-18 Four-year Cohort Graduation Rate']]

# %%
state_grads.columns = ['District Name', 'Total', 'Graduation Rate']

# %%
state_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197 entries, 30 to 13602
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   District Name    197 non-null    object
#  1   Total            197 non-null    object
#  2   Graduation Rate  197 non-null    object
# dtypes: object(3)
# memory usage: 6.2+ KB

# %% [markdown]
# Convert data types.

# %%
state_grads['Graduation Rate'] = state_grads['Graduation Rate'].astype(str).str.replace('--', '')

# %%
state_grads['Total'] = pd.to_numeric(state_grads['Total'])
state_grads['Graduation Rate'] = pd.to_numeric(state_grads['Graduation Rate']) / 100

# %% [markdown]
# Check for matches and non-matches in the two lists.

# %%
state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.upper().str.strip()
state_grads['District Name'] = state_grads['District Name'].astype(str).str.upper().str.strip()

# %%
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' SCHOOL DISTRICT', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace('SCH DIST', 'SCHOOL DISTRICT')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' CS', ' CHARTER SCHOOL')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(r'\sHIGH\sSCHOOL$', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(r'\sSCHOOL$', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' PUBLIC SCHOOLS', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' CO ', ' COUNTY ')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' BORO', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' CITY', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace('TWP', 'TOWNSHIP')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(r'\sREG(\s|$)', ' REGIONAL ')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(r'\sTOWN$', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(r'\sTOWNSHIP$', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(r'\sBORO$', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(r'\sPUBLIC$', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace('H.S DIST.', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(r'^N\s', 'NORTH ')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(r'^W\s', 'WEST ')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace("’", "'")
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' REGIONAL', '')

# state_grads['District Name'] = state_grads['District Name'].astype(str).str.strip()

# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' BOARD OF EDUCATION', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' VOCATIONAL TECHNICAL', ' VOCATIONAL')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' CITY', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' PUBLIC SCHOOLS', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' PUBLIC', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' SCHOOL DISTRICT', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(r'\sHIGH\sSCHOOL$', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(r'\sSCHOOL$', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(r'\sTOWNSHIP$', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(r'\sTOWN$', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(r'\sBOROUGH$', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(r'\sBORO$', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(r'\sDISTRICT$', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace('VOCATIONAL AND TECHNICAL', 'VOCATIONAL')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace('VOCATIONAL-TECHNICAL', 'VOCATIONAL')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace('TECHNICAL', 'VOCATIONAL')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace('INSTITUTE OF TECHNOLOGY', 'VOCATIONAL')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace('SCHOOLS OF TECHNOLOGY', 'VOCATIONAL')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(r'\sHIGH$', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' REGIONAL', '')

# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.strip()

# %%
matches = [name for name in list(state_grads['District Name']) if name in list(state_fiscal['NAME'])]
matches.sort()
len(matches)
# Out:
# 184

# %%
A = [name for name in list(state_grads['District Name']) if name not in list(state_fiscal['NAME'])]
A.sort()
A
# Out:
# ['Adel SD 21',
#  'Arock SD 81',
#  'Ashwood SD 8',
#  'Black Butte SD 41',
#  'Diamond SD 7',
#  'Double O SD 28',
#  'Drewsey SD 13',
#  'Harney County SD 4',
#  'Juntura SD 12',
#  'Pine Creek SD 5',
#  'South Harney SD 33',
#  'Suntex SD 10',
#  'Troy SD 54']

# %%
B = [name for name in list(state_fiscal['NAME']) if name not in list(state_grads['District Name'])]
B.sort()
B
# Out:
# ['Clackamas ESD',
#  'Columbia Gorge ESD',
#  'Douglas ESD',
#  'Grant ESD',
#  'Harney ESD Region XVII',
#  'High Desert ESD',
#  'InterMountain ESD',
#  'Jefferson ESD',
#  'Lake ESD',
#  'Lane ESD',
#  'Linn Benton Lincoln ESD',
#  'Malheur County SD 51',
#  'Malheur ESD Region 14',
#  'Multnomah ESD',
#  'North Central ESD',
#  'Northwest Regional ESD',
#  'ODE Head Start',
#  'ODE Hospital Program District',
#  'ODE JDEP District',
#  'ODE LTCT District',
#  'Oregon Department of Education',
#  'Region 18 ESD',
#  'South Coast ESD',
#  'Southern Oregon ESD',
#  'Willamette ESD']

# %% [markdown]
# No additional matches I can find.

# %%
# state_fiscal_rename = {}

# %%
# state_fiscal = state_fiscal.replace(state_fiscal_rename)

# %% [markdown]
# Merge federal and state data, keeping only matches between the two.

# %%
state_grads_merged = pd.merge(state_fiscal, state_grads, how='inner', left_on='NAME', right_on='District Name')

# %%
state_Grads

# %% [markdown]
# Save cleaned data.

# %%
state_grads_merged.to_csv('../../data/state_data_merged/' + abbr + '.csv', index=False)
