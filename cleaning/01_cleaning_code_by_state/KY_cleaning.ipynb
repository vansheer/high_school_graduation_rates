# %%
import pandas as pd
import numpy as np

# %%
abbr = 'KY'

# %%
file = 'kentucky2019.xlsx'

# %% [markdown]
# Read in federal level data

# %%
fiscal = pd.read_sas('../../data/fiscal2018', format = 'sas7bdat', encoding='iso-8859-1')

# %% [markdown]
# Generate list of districts in the state in the federal data

# %%
state_fiscal = fiscal[(fiscal['STABBR'] == abbr) & (fiscal['GSHI'] == '12')]

# %%
len(state_fiscal)
# Out:
# 171

# %%
state_fiscal.head()
# Out:
#         LEAID        CENSUSID FIPST  CONUM  CSA   CBSA  \
# 5656  2100030  18500100100000    21  21001    N      N
# 5657  2100070  18500200100000    21  21003  150  14540
# 5658  2100081  18508900300000    21  21177    N  16420
# 5660  2100094               N    21  21111  350  31140
# 5661  2100095               N    21  21021    N  19220
#
#                                NAME    STNAME STABBR SCHLEV  ... FL_66V  \
# 5656                   Adair County  Kentucky     KY     03  ...      M
# 5657                   Allen County  Kentucky     KY     03  ...      M
# 5658              Muhlenberg County  Kentucky     KY     03  ...      M
# 5660  Kentucky School for the Blind  Kentucky     KY     03  ...      N
# 5661   Kentucky School for the Deaf  Kentucky     KY     03  ...      N
#
#      FL_W01 FL_W31 FL_W61 FL_V95 FL_V02  FL_K14  FL_CE1  FL_CE2  FL_CE3
# 5656      R      R      R      R      R       R       R       R       M
# 5657      R      R      R      R      R       R       R       R       M
# 5658      R      R      R      R      R       R       R       R       M
# 5660      N      N      N      N      N       N       N       N       N
# 5661      N      N      N      N      N       N       N       N       N
#
# [5 rows x 262 columns]

# %% [markdown]
# Read in state level data

# %%
state_grads = pd.read_excel('../../data/state_data_raw/' + file)

# %%
state_grads.head()
# Out:
#    Code  District Name School Name Gender Race/Ethnicity English Learners  \
# 0     1  Adair County                ---            ---              ---
# 1     1  Adair County                ---            ---              ---
# 2     1  Adair County                ---            ---              ---
# 3     1  Adair County                ---            ---              ---
# 4     1  Adair County                ---            ---               No
#
#   Economically Disadvantaged Students With Disabilities Cohort Population  \
# 0                        No                         No                 63
# 1                        No                        Yes                  1
# 2                       Yes                         No                 99
# 3                       Yes                        Yes                 13
# 4                       ---                         No                160
#
#   Number of Graduates 4 Year Cohort Rate
# 0                  63                100
# 1
# 2                  98                 99
# 3                   7               53.8
# 4                 159               99.4

# %% [markdown]
# Filter samples.

# %%
state_grads = state_grads[(state_grads['School Name'] == '  ') &
                          (state_grads['Gender'] == '--- ') &
                          (state_grads['Race/Ethnicity'] == '--- ') &
                          (state_grads['English Learners'] == '--- ') &
                          (state_grads['Economically Disadvantaged'] == 'No ') &
                          (state_grads['Students With Disabilities'] == 'No ')]

# %%
state_grads
# Out:
#        Code         District Name School Name Gender Race/Ethnicity  \
# 0         1         Adair County                ---            ---
# 490       5         Allen County                ---            ---
# 904      11      Anderson County                ---            ---
# 1542     12  Ashland Independent                ---            ---
# 1940     13  Augusta Independent                ---            ---
# ...     ...                   ...         ...    ...            ...
# 97157   906       ED COOP - OVEC                ---            ---
# 97617   907       ED COOP - SESC                ---            ---
# 98049   908       ED COOP - WKEC                ---            ---
# 98481   909    ED COOP - JEFF CO                ---            ---
# 98991   999                State                ---            ---
#
#       English Learners Economically Disadvantaged Students With Disabilities  \
# 0                 ---                         No                         No
# 490               ---                         No                         No
# 904               ---                         No                         No
# 1542              ---                         No                         No
# 1940              ---                         No                         No
# ...                ...                        ...                        ...
# 97157             ---                         No                         No
# 97617             ---                         No                         No
# 98049             ---                         No                         No
# 98481             ---                         No                         No
# 98991             ---                         No                         No
#
#       Cohort Population Number of Graduates 4 Year Cohort Rate
# 0                    63                  63                100
# 490                 106                 106                100
# 904                 133                 131               98.5
# 1542                119                 118               99.2
# 1940                  9
# ...                 ...                 ...                ...
# 97157              2400                2342               97.6
# 97617              1909                1861               97.5
# 98049              2222                2168               97.6
# 98481              3386                2796               82.6
# 98991             22512               21310               94.7
#
# [178 rows x 11 columns]

# %% [markdown]
# Select and rename columns.

# %%
state_grads = state_grads[['District Name', 'Cohort Population', '4 Year Cohort Rate']]

# %%
state_grads.columns = ['District Name', 'Total', 'Graduation Rate']

# %%
state_grads
# Out:
#               District Name  Total Graduation Rate
# 0             Adair County      63             100
# 490           Allen County     106             100
# 904        Anderson County     133            98.5
# 1542   Ashland Independent     119            99.2
# 1940   Augusta Independent       9
# ...                     ...    ...             ...
# 97157       ED COOP - OVEC    2400            97.6
# 97617       ED COOP - SESC    1909            97.5
# 98049       ED COOP - WKEC    2222            97.6
# 98481    ED COOP - JEFF CO    3386            82.6
# 98991                State   22512            94.7
#
# [178 rows x 3 columns]

# %%
state_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178 entries, 0 to 98991
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   District Name    178 non-null    object
#  1   Total            178 non-null    object
#  2   Graduation Rate  178 non-null    object
# dtypes: object(3)
# memory usage: 5.6+ KB

# %% [markdown]
# Convert data types.

# %%
state_grads = state_grads.replace('  ', '')

# %%
state_grads['District Name'] = state_grads['District Name'].astype(str).str.strip()

# %%
state_grads['Total'] = pd.to_numeric(state_grads['Total'])
state_grads['Graduation Rate'] = pd.to_numeric(state_grads['Graduation Rate']) / 100

# %% [markdown]
# Check for matches and non-matches in the two lists

# %%
Matches = [name for name in list(state_grads['District Name']) if name in list(state_fiscal['NAME'])]
Matches.sort()
len(Matches)
# Out:
# 163

# %%
A = [name for name in list(state_grads['District Name']) if name not in list(state_fiscal['NAME'])]
A.sort()
A
# Out:
# ['ED COOP - CKEC',
#  'ED COOP - GRREC',
#  'ED COOP - JEFF CO',
#  'ED COOP - KEDC',
#  'ED COOP - KVEC',
#  'ED COOP - NKCES',
#  'ED COOP - OVEC',
#  'ED COOP - SESC',
#  'ED COOP - WKEC',
#  'Larue County',
#  'Mccracken County',
#  'Mccreary County',
#  'Mclean County',
#  'Raceland-Worthington Independe',
#  'State']

# %%
B = [name for name in list(state_fiscal['NAME']) if name not in list(state_grads['District Name'])]
B.sort()
B
# Out:
# ['Kentucky School for the Blind',
#  'Kentucky School for the Deaf',
#  'Kentucky Tech System',
#  'LaRue County',
#  'McCracken County',
#  'McCreary County',
#  'McLean County',
#  'Raceland-Worthington Independent']

# %%
state_grads_rename = {
    'Larue County' : 'LaRue County',
    'Mccracken County' : 'McCracken County',
    'Mccreary County' : 'McCreary County',
    'Mclean County' : 'McLean County',
    'Raceland-Worthington Independe' : 'Raceland-Worthington Independent'
}

# %%
state_grads = state_grads.replace(state_grads_rename)

# %% [markdown]
# Merge federal and state data, keeping only matches between the two.

# %%
state_grads_merged = pd.merge(state_fiscal, state_grads, how='inner', left_on='NAME', right_on='District Name')

# %% [markdown]
# Save cleaned data.

# %%
state_grads_merged.to_csv('../../data/state_data_merged/' + abbr + '.csv', index=False)
