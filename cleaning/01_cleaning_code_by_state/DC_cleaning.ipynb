# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %%
abbr = 'DC'

# %%
file = 'dc2018.xlsx'

# %% [markdown]
# Read in federal level data

# %%
fiscal = pd.read_sas('../../data/fiscal2018', format = 'sas7bdat', encoding='iso-8859-1')

# %% [markdown]
# Generate list of districts in the state in the federal data

# %%
state_fiscal = fiscal[(fiscal['STABBR'] == abbr) & (fiscal['GSHI'] == '12')]

# %%
len(state_fiscal)
# Out:
# 22

# %%
state_fiscal
# Out:
#         LEAID        CENSUSID FIPST  CONUM  CSA   CBSA  \
# 2945  1100005               N    11  11001  548  47900
# 2946  1100008               N    11  11001  548  47900
# 2950  1100013               N    11  11001  548  47900
# 2951  1100014               N    11  11001  548  47900
# 2955  1100019               N    11  11001  548  47900
# 2957  1100022               N    11  11001  548  47900
# 2958  1100026               N    11  11001  548  47900
# 2960  1100030  09200100130100    11  11001  548  47900
# 2961  1100031               N    11  11001  548  47900
# 2963  1100034               N    11  11001  548  47900
# 2964  1100035               N    11  11001  548  47900
# 2965  1100039               N    11  11001  548  47900
# 2967  1100043               N    11  11001  548  47900
# 2979  1100064               N    11  11001  548  47900
# 2985  1100079               N    11  11001  548  47900
# 2988  1100082               N    11  11001  548  47900
# 2989  1100083               N    11  11001  548  47900
# 2993  1100087               N    11  24003  548  12580
# 2995  1100089               N    11  11001  548  47900
# 3005  1100099               N    11  11001  548  47900
# 3011  1100105               N    11  11001  548  47900
# 3013  1100107               N    11  11001  548  47900
#
#                                                   NAME                STNAME  \
# 2945                Cesar Chavez PCS for Public Policy  District of Columbia
# 2946                                    Friendship PCS  District of Columbia
# 2950                                          IDEA PCS  District of Columbia
# 2951                                  Maya Angelou PCS  District of Columbia
# 2955                              Washington Latin PCS  District of Columbia
# 2957                         SEED PCS of Washington DC  District of Columbia
# 2958    Washington Mathematics Science Technology PCHS  District of Columbia
# 2960               District of Columbia Public Schools  District of Columbia
# 2961                                       KIPP DC PCS  District of Columbia
# 2963                     Thurgood Marshall Academy PCS  District of Columbia
# 2964                                  Capital City PCS  District of Columbia
# 2965                                          Paul PCS  District of Columbia
# 2967                                   E.L. Haynes PCS  District of Columbia
# 2979                 St. Coletta Special Education PCS  District of Columbia
# 2985              National Collegiate Preparatory PCHS  District of Columbia
# 2988  Richard Wright PCS for Journalism and Media Arts  District of Columbia
# 2989                                      Basis DC PCS  District of Columbia
# 2993                                              DYRS  District of Columbia
# 2995                  Somerset Preparatory Academy PCS  District of Columbia
# 3005                              Kingsman Academy PCS  District of Columbia
# 3011                         Goodwill Excel Center PCS  District of Columbia
# 3013                           Sustainable Futures PCS  District of Columbia
#
#      STABBR SCHLEV  ... FL_66V FL_W01 FL_W31 FL_W61 FL_V95 FL_V02  FL_K14  \
# 2945     DC     03  ...      R      R      R      R      R      R       R
# 2946     DC     03  ...      R      R      R      R      R      R       R
# 2950     DC     02  ...      R      R      R      R      I      R       I
# 2951     DC     02  ...      R      R      R      R      R      R       R
# 2955     DC     03  ...      R      R      R      R      R      R       R
# 2957     DC     03  ...      R      R      R      R      R      R       R
# 2958     DC     02  ...      M      M      M      M      M      M       M
# 2960     DC     03  ...      R      R      R      R      R      R       R
# 2961     DC     03  ...      R      R      R      R      R      R       R
# 2963     DC     02  ...      R      R      R      R      R      R       R
# 2964     DC     03  ...      R      R      R      R      R      R       R
# 2965     DC     03  ...      R      R      R      R      R      R       R
# 2967     DC     03  ...      R      R      R      R      R      R       R
# 2979     DC     03  ...      R      R      R      R      R      R       R
# 2985     DC     02  ...      R      R      R      R      R      R       R
# 2988     DC     02  ...      R      R      R      R      R      R       R
# 2989     DC     03  ...      R      R      R      R      R      R       I
# 2993     DC     02  ...      R      R      R      R      R      R       R
# 2995     DC     03  ...      R      R      R      R      R      R       R
# 3005     DC     03  ...      R      R      R      R      R      R       R
# 3011     DC     02  ...      R      R      R      R      R      R       R
# 3013     DC     02  ...      R      R      R      R      R      R       R
#
#       FL_CE1  FL_CE2  FL_CE3
# 2945       R       R       M
# 2946       R       R       M
# 2950       R       R       M
# 2951       R       R       M
# 2955       R       R       M
# 2957       R       R       M
# 2958       M       M       M
# 2960       R       R       M
# 2961       I       R       M
# 2963       R       R       M
# 2964       R       R       M
# 2965       R       R       M
# 2967       R       R       M
# 2979       R       R       M
# 2985       R       R       M
# 2988       R       R       M
# 2989       R       R       M
# 2993       R       R       M
# 2995       R       R       M
# 3005       R       R       M
# 3011       I       I       M
# 3013       R       R       M
#
# [22 rows x 262 columns]

# %% [markdown]
# Read in state level data

# %%
state_grads = pd.read_excel('../../data/state_data_raw/' + file, sheet_name = '2017-18 Rate by School')

# %%
state_grads.head()
# Out:
#   DC 2018 4-year Adjusted Cohort Graduation Rates, Unnamed: 1    Unnamed: 2  \
# 0                                        by School        NaN           NaN
# 1                                              NaN        NaN           NaN
# 2                                           School  Graduates  Cohort Total
# 3                                              All       3330          4863
# 4                                   Charter Cohort       1053          1454
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2  2017 ACGR
# 3      68.5%
# 4      72.4%

# %% [markdown]
# Reset columns.

# %%
state_grads.columns = state_grads.loc[2]
state_grads = state_grads.loc[4:28]

# %%
state_grads
# Out:
# 2                                              School Graduates Cohort Total  \
# 4                                      Charter Cohort      1053         1454
# 5                                        BASIS DC PCS        16           16
# 6                      Capital City PCS - High School        61           71
# 7   Cesar Chavez PCS for Public Policy - Capitol Hill        56           74
# 8    Cesar Chavez PCS for Public Policy - Chavez Prep      n<10         n<10
# 9   Cesar Chavez PCS for Public Policy - Parkside ...        56           65
# 10                      E.L. Haynes PCS - High School        93          109
# 11                Friendship PCS - Collegiate Academy       142          188
# 12  Friendship PCS - Technology Preparatory High S...        41           48
# 13                          Goodwill Excel Center PCS         2           29
# 14                                           IDEA PCS        39           71
# 15          KIPP DC - College Preparatory Academy PCS        97          114
# 16                               Kingsman Academy PCS        16           66
# 17                     Maya Angelou PCS - High School        32           68
# 18               National Collegiate Preparatory PCHS        35           59
# 19               Paul PCS - International High School        71           81
# 20   Richard Wright PCS for Journalism and Media Arts        44           53
# 21                          SEED PCS of Washington DC        25           25
# 22                   Somerset Preparatory Academy PCS        23           26
# 23                            Sustainable Futures PCS         0           11
# 24                      Thurgood Marshall Academy PCS        62           79
# 25                Washington Latin PCS - Upper School        69           79
# 26                  Washington Leadership Academy PCS      n<10         n<10
# 27     Washington Mathematics Science Technology PCHS        63           78
# 28                                        DCPS Cohort      2273         3311
#
# 2  2017 ACGR
# 4      72.4%
# 5     100.0%
# 6      85.9%
# 7      75.7%
# 8        NaN
# 9      86.2%
# 10     85.3%
# 11     75.5%
# 12     85.4%
# 13      6.9%
# 14     54.9%
# 15     85.1%
# 16     24.2%
# 17     47.1%
# 18     59.3%
# 19     87.7%
# 20     83.0%
# 21    100.0%
# 22     88.5%
# 23      0.0%
# 24     78.5%
# 25     87.3%
# 26       NaN
# 27     80.8%
# 28     68.6%

# %% [markdown]
# Filter results.

# %%
# state_grads = state_grads[(state_grads['SCHOOL_NAME'] == '[Districtwide]') &
#                          (state_grads['GROUP_BY_VALUE'] == 'All Students') &
#                          (state_grads['TIMEFRAME'] == '4-Year rate') &
#                          (state_grads['COMPLETION_STATUS'] == 'Completed - Regular High School Diploma')]

# %% [markdown]
# Select and rename columns.

# %%
state_grads.drop(columns='Graduates', inplace=True)

# %%
state_grads.head()
# Out:
# 2                                             School Cohort Total 2017 ACGR
# 4                                     Charter Cohort         1454     72.4%
# 5                                       BASIS DC PCS           16    100.0%
# 6                     Capital City PCS - High School           71     85.9%
# 7  Cesar Chavez PCS for Public Policy - Capitol Hill           74     75.7%
# 8   Cesar Chavez PCS for Public Policy - Chavez Prep         n<10       NaN

# %%
state_grads.columns = ['District Name', 'Total', 'Graduation Rate']

# %%
state_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 4 to 28
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   District Name    25 non-null     object
#  1   Total            25 non-null     object
#  2   Graduation Rate  23 non-null     object
# dtypes: object(3)
# memory usage: 732.0+ bytes

# %% [markdown]
# Convert data types.

# %%
state_grads['Total'] = state_grads['Total'].astype(str).str.replace('n<10', '')
state_grads['Total'] = state_grads['Total'].astype(str).str.replace('nan', '')
state_grads['Graduation Rate'] = state_grads['Graduation Rate'].astype(str).str.replace('%', '')
state_grads['Graduation Rate'] = state_grads['Graduation Rate'].astype(str).str.replace('nan', '')
state_grads = state_grads.fillna('')

# %%
state_grads['Total'] = pd.to_numeric(state_grads['Total'])
state_grads['Graduation Rate'] = pd.to_numeric(state_grads['Graduation Rate']) / 100

# %% [markdown]
# For DC, two charter systems have high schools reporting their graduation rates individually, so I will add them manually. Because Chavez Prep's numbers are < 10, they are not reported and will not be included in the sum.

# %%
addon = pd.DataFrame({'District Name' : {0 : 'Cesar Chavez PCS for Public Policy', 1 : 'Friendship PCS'},
             'Total' : {0 : (74 + 65), 1 : (188 + 48)},
             'Graduation Rate' : {0 : ((56 + 56) / (74 + 65)), 1 : ((142 + 41) / (188 + 48))}})

# %%
state_grads = pd.concat([state_grads, addon], ignore_index=True)

# %% [markdown]
# Check for matches and non-matches in the two lists.

# %%
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.upper().str.strip()
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.upper().str.strip()

# %%
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(r'\sSu$', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(r'\sSd$', '')

# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' County School District', '')
# state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' # ', ' #')

# %%
matches = [name for name in list(state_grads['District Name']) if name in list(state_fiscal['NAME'])]
matches.sort()
len(matches)
# Out:
# 12

# %%
A = [name for name in list(state_grads['District Name']) if name not in list(state_fiscal['NAME'])]
A.sort()
A
# Out:
# ['BASIS DC PCS',
#  'Capital City PCS - High School',
#  'Cesar Chavez PCS for Public Policy - Capitol Hill',
#  'Cesar Chavez PCS for Public Policy - Chavez Prep',
#  'Cesar Chavez PCS for Public Policy - Parkside High School',
#  'Charter Cohort',
#  'DCPS Cohort',
#  'E.L. Haynes PCS - High School',
#  'Friendship PCS - Collegiate Academy',
#  'Friendship PCS - Technology Preparatory High School',
#  'KIPP DC - College Preparatory Academy PCS',
#  'Maya Angelou PCS - High School',
#  'Paul PCS - International High School',
#  'Washington Latin PCS - Upper School',
#  'Washington Leadership Academy PCS']

# %%
B = [name for name in list(state_fiscal['NAME']) if name not in list(state_grads['District Name'])]
B.sort()
B
# Out:
# ['Basis DC PCS',
#  'Capital City PCS',
#  'DYRS',
#  'District of Columbia Public Schools',
#  'E.L. Haynes PCS',
#  'KIPP DC PCS',
#  'Maya Angelou PCS',
#  'Paul PCS',
#  'St. Coletta Special Education PCS',
#  'Washington Latin PCS']

# %% [markdown]
# Make any additional matches.

# %%
state_grads_rename = {
    'BASIS DC PCS' : 'Basis DC PCS',
    'Capital City PCS - High School' : 'Capital City PCS',
#     'Cesar Chavez PCS for Public Policy - Capitol Hill',
#     'Cesar Chavez PCS for Public Policy - Chavez Prep',
#     'Cesar Chavez PCS for Public Policy - Parkside High School',
#     'Charter Cohort',
    'DCPS Cohort' : 'District of Columbia Public Schools',
    'E.L. Haynes PCS - High School' : 'E.L. Haynes PCS - High School',
    'Friendship PCS - Collegiate Academy',
    'Friendship PCS - Technology Preparatory High School',
    'KIPP DC - College Preparatory Academy PCS',
    'Maya Angelou PCS - High School',
    'Paul PCS - International High School',
    'Washington Latin PCS - Upper School',
    'Washington Leadership Academy PCS'
}
# Out:
#   File "<ipython-input-27-9b37f2bb7a1e>", line 4
#     'Cesar Chavez PCS for Public Policy',
#                                         ^
# SyntaxError: invalid syntax

# %%
# state_fiscal = state_fiscal.replace(state_fiscal_rename)

# %% [markdown]
# Merge federal and state data, keeping only matches between the two.

# %%
state_grads_merged = pd.merge(state_fiscal, state_grads, how='inner', left_on='NAME', right_on='District Name')

# %% [markdown]
# Save cleaned data.

# %%
state_grads_merged.to_csv('../../data/state_data_merged/' + abbr + '.csv', index=False)
