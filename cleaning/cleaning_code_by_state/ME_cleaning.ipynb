# %%
import pandas as pd
import numpy as np

# %%
abbr = 'ME'

# %%
file = 'maine2018.xlsx'

# %% [markdown]
# Read in federal level data

# %%
fiscal = pd.read_sas('../../data/fiscal2018', format = 'sas7bdat', encoding='iso-8859-1')

# %% [markdown]
# Generate list of districts in the state in the federal data

# %%
state_fiscal = fiscal[(fiscal['STABBR'] == abbr) & (fiscal['GSHI'] == '12')]

# %%
len(state_fiscal)
# Out:
# 249

# %%
state_fiscal.head()
# Out:
#         LEAID        CENSUSID FIPST  CONUM  CSA   CBSA  \
# 6051  2300004  20300200730100    23  23003    N      N
# 6052  2300005  20300202430100    23  23003    N      N
# 6053  2300008  20300600930100    23  23011    N  12300
# 6054  2300009  20300320130100    23  23005  438  38860
# 6055  2300049  20000000010100    23  23003    N      N
#
#                                  NAME STNAME STABBR SCHLEV  ... FL_66V FL_W01  \
# 6051       Bridgewater Public Schools  Maine     ME     06  ...      M      M
# 6052        Grand Isle Public Schools  Maine     ME     06  ...      M      M
# 6053           Fayette Public Schools  Maine     ME     01  ...      M      M
# 6054       Long Island Public Schools  Maine     ME     01  ...      M      M
# 6055  ME Sch of Science & Mathematics  Maine     ME     02  ...      M      M
#
#      FL_W31 FL_W61 FL_V95 FL_V02  FL_K14  FL_CE1  FL_CE2  FL_CE3
# 6051      R      R      R      R       R       R       R       R
# 6052      R      R      R      R       R       R       R       R
# 6053      R      R      R      R       R       I       I       R
# 6054      R      R      R      R       R       R       R       R
# 6055      R      R      R      R       R       I       I       R
#
# [5 rows x 262 columns]

# %% [markdown]
# Read in state level data

# %%
state_grads = pd.read_excel('../../data/state_data_raw/' + file, sheet_name='details')

# %%
state_grads.head()
# Out:
#    Year Code  District ID               District Name  School ID  School Name  \
# 0       2018       1069.0  Arthur R. Gould Sch--LCYDC        NaN  All Schools
# 1       2018       1069.0  Arthur R. Gould Sch--LCYDC        NaN  All Schools
# 2       2018       1069.0  Arthur R. Gould Sch--LCYDC        NaN  All Schools
# 3       2018       1069.0  Arthur R. Gould Sch--LCYDC        NaN  All Schools
# 4       2018       1069.0  Arthur R. Gould Sch--LCYDC        NaN  All Schools
#
#      Graduation               Disaggregated    Population  \
# 0  GRADRT4YRADJ                All Students  All Students
# 1  GRADRT4YRADJ     Children in Foster Care            No
# 2  GRADRT4YRADJ     Children in Foster Care           Yes
# 3  GRADRT4YRADJ  Children with Disabilities            No
# 4  GRADRT4YRADJ  Children with Disabilities           Yes
#
#   Adjusted Cohort Count Graduate Count Student Rate District Rate  \
# 0                    27              9        33.33           NaN
# 1                    24              9        37.50           NaN
# 2                     *              *            *             *
# 3                     *              *            *             *
# 4                    19              6        31.58           NaN
#
#   Statewide Rate
# 0          86.74
# 1          86.86
# 2              *
# 3              *
# 4          73.55

# %% [markdown]
# Filter results.

# %%
state_grads = state_grads[(state_grads['School Name'] == 'All Schools') &
                         (state_grads['Graduation'] == 'GRADRT4YRADJ') &
                         (state_grads['Disaggregated'] == 'All Students')]

# %%
state_grads
# Out:
#        Year Code  District ID               District Name  School ID  \
# 0           2018       1069.0  Arthur R. Gould Sch--LCYDC        NaN
# 96          2018         14.0       Auburn Public Schools        NaN
# 192         2018         28.0      Augusta Public Schools        NaN
# 288         2018         38.0  Baileyville Public Schools        NaN
# 384         2018         42.0       Bangor Public Schools        NaN
# ...          ...          ...                         ...        ...
# 11808       2018        518.0             Winslow Schools        NaN
# 11904       2018        524.0     Winthrop Public Schools        NaN
# 12000       2018       1671.0    Wiscasset Public Schools        NaN
# 12096       2018        537.0            Yarmouth Schools        NaN
# 12192       2018        542.0         York Public Schools        NaN
#
#        School Name    Graduation Disaggregated    Population  \
# 0      All Schools  GRADRT4YRADJ  All Students  All Students
# 96     All Schools  GRADRT4YRADJ  All Students  All Students
# 192    All Schools  GRADRT4YRADJ  All Students  All Students
# 288    All Schools  GRADRT4YRADJ  All Students  All Students
# 384    All Schools  GRADRT4YRADJ  All Students  All Students
# ...            ...           ...           ...           ...
# 11808  All Schools  GRADRT4YRADJ  All Students  All Students
# 11904  All Schools  GRADRT4YRADJ  All Students  All Students
# 12000  All Schools  GRADRT4YRADJ  All Students  All Students
# 12096  All Schools  GRADRT4YRADJ  All Students  All Students
# 12192  All Schools  GRADRT4YRADJ  All Students  All Students
#
#       Adjusted Cohort Count Graduate Count Student Rate District Rate  \
# 0                        27              9        33.33           NaN
# 96                      244            190        77.87           NaN
# 192                     185            147        79.46           NaN
# 288                      25             24           96           NaN
# 384                     280            237        84.64           NaN
# ...                     ...            ...          ...           ...
# 11808                   116            103        88.79           NaN
# 11904                    53             46        86.79           NaN
# 12000                    45             37        82.22           NaN
# 12096                   129            128        99.22           NaN
# 12192                   148            140        94.59           NaN
#
#       Statewide Rate
# 0              86.74
# 96             86.74
# 192            86.74
# 288            86.74
# 384            86.74
# ...              ...
# 11808          86.74
# 11904          86.74
# 12000          86.74
# 12096          86.74
# 12192          86.74
#
# [120 rows x 13 columns]

# %% [markdown]
# Select and rename columns.

# %%
state_grads = state_grads[['District Name', 'Adjusted Cohort Count', 'Student Rate']]

# %%
state_grads.columns = ['District Name', 'Total', 'Graduation Rate']

# %%
state_grads
# Out:
#                     District Name Total Graduation Rate
# 0      Arthur R. Gould Sch--LCYDC    27           33.33
# 96          Auburn Public Schools   244           77.87
# 192        Augusta Public Schools   185           79.46
# 288    Baileyville Public Schools    25              96
# 384         Bangor Public Schools   280           84.64
# ...                           ...   ...             ...
# 11808             Winslow Schools   116           88.79
# 11904     Winthrop Public Schools    53           86.79
# 12000    Wiscasset Public Schools    45           82.22
# 12096            Yarmouth Schools   129           99.22
# 12192         York Public Schools   148           94.59
#
# [120 rows x 3 columns]

# %%
state_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 0 to 12192
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   District Name    120 non-null    object
#  1   Total            120 non-null    object
#  2   Graduation Rate  119 non-null    object
# dtypes: object(3)
# memory usage: 3.8+ KB

# %% [markdown]
# Convert data types.

# %%
state_grads = state_grads.replace('*', '')

# %%
state_grads['Total'] = pd.to_numeric(state_grads['Total'])
state_grads['Graduation Rate'] = pd.to_numeric(state_grads['Graduation Rate']) / 100

# %% [markdown]
# Check for matches and non-matches in the two lists

# %%
Matches = [name for name in list(state_grads['District Name']) if name in list(state_fiscal['NAME'])]
Matches.sort()
Matches
# Out:
# ['Arthur R. Gould Sch--LCYDC',
#  'Auburn Public Schools',
#  'Augusta Public Schools',
#  'Baileyville Public Schools',
#  'Bangor Public Schools',
#  'Baxter Academy for Technology and Science',
#  'Biddeford Public Schools',
#  'Boothbay-Boothbay Hbr CSD',
#  'Brewer Public Schools',
#  'Brunswick Public Schools',
#  'Calais Public Schools',
#  'Cape Elizabeth Public Schools',
#  'Cornville Regional Charter School',
#  'Deer Isle-Stonington CSD',
#  'East Millinocket Public Schools',
#  'Easton Public Schools',
#  'Eastport Public Schools',
#  'Ellsworth Public Schools',
#  'Falmouth Public Schools',
#  'Five Town CSD',
#  'Gorham Public Schools',
#  'Greenville Public Schools',
#  'Harpswell Coastal Academy',
#  'Hermon Public Schools',
#  'Islesboro Public Schools',
#  'Kittery Public Schools',
#  'Lewiston Public Schools',
#  'Lisbon Public Schools',
#  'ME Sch of Science & Mathematics',
#  'MSAD 27',
#  'MSAD 46',
#  'Machias Public Schools',
#  'Madawaska Public Schools',
#  'Maine Academy of Natural Sciences',
#  'Maine Connections Academy',
#  'Maine Virtual Academy',
#  'Millinocket Public Schools',
#  'Moosabec CSD',
#  'Mt Desert CSD',
#  'Portland Public Schools',
#  'RSU 01 - LKRSU',
#  'RSU 02',
#  'RSU 03/MSAD 03',
#  'RSU 04',
#  'RSU 05',
#  'RSU 06/MSAD 06',
#  'RSU 07/MSAD 07',
#  'RSU 08/MSAD 08',
#  'RSU 09',
#  'RSU 10',
#  'RSU 11/MSAD 11',
#  'RSU 13',
#  'RSU 14',
#  'RSU 15/MSAD 15',
#  'RSU 16',
#  'RSU 17/MSAD 17',
#  'RSU 18',
#  'RSU 19',
#  'RSU 20',
#  'RSU 21',
#  'RSU 22',
#  'RSU 23',
#  'RSU 24',
#  'RSU 25',
#  'RSU 26',
#  'RSU 29/MSAD 29',
#  'RSU 31/MSAD 31',
#  'RSU 32/MSAD 32',
#  'RSU 33/MSAD 33',
#  'RSU 34',
#  'RSU 35/MSAD 35',
#  'RSU 37/MSAD 37',
#  'RSU 38',
#  'RSU 39',
#  'RSU 40/MSAD 40',
#  'RSU 41/MSAD 41',
#  'RSU 42/MSAD 42',
#  'RSU 44/MSAD 44',
#  'RSU 45/MSAD 45',
#  'RSU 49/MSAD 49',
#  'RSU 50',
#  'RSU 51/MSAD 51',
#  'RSU 52/MSAD 52',
#  'RSU 53/MSAD 53',
#  'RSU 54/MSAD 54',
#  'RSU 55/MSAD 55',
#  'RSU 56',
#  'RSU 57/MSAD 57',
#  'RSU 58/MSAD 58',
#  'RSU 59/MSAD 59',
#  'RSU 60/MSAD 60',
#  'RSU 61/MSAD 61',
#  'RSU 64/MSAD 64',
#  'RSU 67',
#  'RSU 70/MSAD 70',
#  'RSU 71',
#  'RSU 73',
#  'RSU 74/MSAD 74',
#  'RSU 75/MSAD 75',
#  'RSU 78',
#  'RSU 79/MSAD 01',
#  'RSU 80/MSAD 04',
#  'RSU 82/MSAD 12',
#  'RSU 83/MSAD 13',
#  'RSU 84/MSAD 14',
#  'RSU 86/MSAD 20',
#  'RSU 88/MSAD 24',
#  'Sanford Public Schools',
#  'Scarborough Public Schools',
#  'Snow Pond Arts Academy',
#  'South Portland Public Schools',
#  'Waterville Public Schools',
#  'Wells-Ogunquit CSD',
#  'Westbrook Public Schools',
#  'Winslow Schools',
#  'Winthrop Public Schools',
#  'Wiscasset Public Schools',
#  'Yarmouth Schools',
#  'York Public Schools']

# %%
A = [name for name in list(state_grads['District Name']) if name not in list(state_fiscal['NAME'])]
A.sort()
A
# Out:
# ['Statewide']

# %%
B = [name for name in list(state_fiscal['NAME']) if name not in list(state_grads['District Name'])]
B.sort()
B
# Out:
# ['Acton Public Schools',
#  'Airline CSD',
#  'Alexander Public Schools',
#  'Andover Public Schools',
#  'Athens Public Schools',
#  'Baring Plt Public Schools',
#  'Beaver Cove Public Schools',
#  'Beddington Public Schools',
#  'Blue Hill Public Schools',
#  'Bowerbank Public Schools',
#  'Bremen Public Schools',
#  'Bridgewater Public Schools',
#  'Brighton Plt School Department',
#  'Bristol Public Schools',
#  'Brooklin Public Schools',
#  'Brooksville Public Schools',
#  'Burlington Public Schools',
#  'Byron Public Schools',
#  'Caratunk Public Schools',
#  'Carrabassett Valley Public Schools',
#  'Carroll Plt Public Schools',
#  'Cary Plantation',
#  'Castine Public Schools',
#  'Caswell Public Schools',
#  'Charlotte Public Schools',
#  'Chebeague Island Public Schools',
#  'Cherryfield Public Schools',
#  'Cooper Public Schools',
#  'Coplin Plt Public Schools',
#  'Cranberry Isles Public Schools',
#  'Crawford Public Schools',
#  'Cutler Public Schools',
#  'Damariscotta Public Schools',
#  'Dayton Public Schools',
#  'Deblois Public Schools',
#  'Dedham Public Schools',
#  'Dennistown Plt Public Schools',
#  'Dennysville Public Schools',
#  'Drew Plt Public Schools',
#  'East Machias Public Schools',
#  'East Range CSD',
#  'Edgecomb Public Schools',
#  'Education in Unorganized Terr',
#  'Eustis Public Schools',
#  'Fayette Public Schools',
#  'Frenchboro Public Schools',
#  'Georgetown Public Schools',
#  'Gilead Public Schools',
#  'Glenburn Public Schools',
#  'Glenwood Plt Public Schools',
#  'Grand Isle Public Schools',
#  'Grand Lake Stream Plt School Dept',
#  'Greenbush Public Schools',
#  'Hancock Public Schools',
#  'Harmony Public Schools',
#  'Highland Plt Public Schools',
#  'Indian Island',
#  'Indian Township',
#  'Isle Au Haut Public Schools',
#  'Jefferson Public Schools',
#  'Jonesboro Public Schools',
#  'Kingsbury Plt Public Schools',
#  'Lake View Plt. Public Schools',
#  'Lakeville Public Schools',
#  'Lamoine Public Schools',
#  'Lincoln Plt Public Schools',
#  'Long Island Public Schools',
#  'Lowell Public Schools',
#  'MSAD 10',
#  'MSAD 76',
#  'Machiasport Public Schools',
#  'Macwahoc Plt School Dept',
#  'Marshfield Public Schools',
#  'Meddybemps Public Schools',
#  'Medford Public Schools',
#  'Medway Public Schools',
#  'Milford Public Schools',
#  'Monhegan Plt School Dept',
#  'Nashville Plt Public Schools',
#  'New Sweden Public Schools',
#  'Newcastle Public Schools',
#  'Nobleboro Public Schools',
#  'Northfield Public Schools',
#  'Northport Public Schools',
#  'Orient Public Schools',
#  'Orrington Public Schools',
#  'Otis Public Schools',
#  'Pembroke Public Schools',
#  'Penobscot Public Schools',
#  'Perry Public Schools',
#  'Pleasant Point',
#  'Pleasant Ridge Plt School Dept',
#  'Portage Lake Public Schools',
#  'Princeton Public Schools',
#  'RSU 12',
#  'RSU 30/MSAD 30',
#  'RSU 63/MSAD 63',
#  'RSU 65/MSAD 65',
#  'RSU 68/MSAD 68',
#  'RSU 72/MSAD 72',
#  'RSU 87/MSAD 23',
#  'Reed Plt Public Schools',
#  'Robbinston Public Schools',
#  'Roque Bluffs Public Schools',
#  'Saco Public Schools',
#  'Seboeis Plt Public Schools',
#  'Sedgwick Public Schools',
#  'Shirley Public Schools',
#  'South Bristol Public Schools',
#  'Southport Public Schools',
#  'St George Public Schools',
#  'Surry Public Schools',
#  'Talmadge Public Schools',
#  'The Forks Plt School Dept',
#  'Trenton Public Schools',
#  'Upton Public Schools',
#  'Vanceboro Public Schools',
#  'Vassalboro Public Schools',
#  'Veazie Public Schools',
#  'Waite Public Schools',
#  'Wesley Public Schools',
#  'West Bath Public Schools',
#  'West Forks Plt Public Schools',
#  'Westmanland Public Schools',
#  'Whiting Public Schools',
#  'Whitneyville Public Schools',
#  'Willimantic Public Schools',
#  'Winterville Plt Public Schools',
#  'Woodland Public Schools',
#  'Woodville Public Schools']

# %% [markdown]
# Rename the samples I can find matches for.

# %%
state_grads_rename = {
    #'Algiers Technology Academy',
    #'Community School for Apprenticeship Learning Inc.',
    'Delta Charter Group' : 'Delta Charter School MST',
    'Dr Martin Luther King Charter School for Sci/Tech' : 'Dr. Martin Luther King Charter School for Sci Tech',
    #'Howard School',
    'JCFA Lafayette' : 'JCFA',
    'KIPP Renaissance High School' : 'KIPP Renaissance',
    #'LA Schools for the Deaf and Visually Impaired',
    #'Lake Area New Tech Early College High School',
    #'Louisiana Special Education Center',
    #'The NET2 High School',
    'University View Academy Inc. (FRM LA Connections)' :  'University View Academy, Inc. (FRM LA Connections)',
    #'Voices for International Business & Education'
}

# %%
state_fiscal = state_fiscal.replace(state_grads_rename)

# %% [markdown]
# Merge federal and state data, keeping only matches between the two.

# %%
state_grads_merged = pd.merge(state_fiscal, state_grads, how='inner', left_on='NAME', right_on='District Name')

# %% [markdown]
# Save cleaned data.

# %%
state_grads_merged.to_csv('../../data/state_data_merged/' + abbr + '.csv', index=False)
