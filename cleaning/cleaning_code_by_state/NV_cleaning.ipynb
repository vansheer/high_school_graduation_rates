# %%
import pandas as pd
import numpy as np

# %%
abbr = 'NV'

# %%
file = 'nevada2018.csv'

# %% [markdown]
# Read in federal level data

# %%
fiscal = pd.read_sas('../../data/fiscal2018', format = 'sas7bdat', encoding='iso-8859-1')

# %% [markdown]
# Generate list of districts in the state in the federal data

# %%
state_fiscal = fiscal[(fiscal['STABBR'] == abbr) & (fiscal['GSHI'] == '12')]

# %%
len(state_fiscal)
# Out:
# 20

# %%
state_fiscal.head()
# Out:
#         LEAID        CENSUSID FIPST  CONUM  CSA   CBSA  \
# 9799  3200001               N    32  32510  456  16180
# 9800  3200021               N    32  32031  456  39900
# 9801  3200022               N    32  32003  332  29820
# 9802  3200023               N    32  32007    N  21220
# 9803  3200030  29500100100000    32  32001    N  21980
#
#                                    NAME  STNAME STABBR SCHLEV  ... FL_66V  \
# 9799    STATE-SPONSORED CHARTER SCHOOLS  Nevada     NV     03  ...      R
# 9800  DAVIDSON ACADEMY  SCHOOL DISTRICT  Nevada     NV     03  ...      R
# 9801        ACHIEVEMENT SCHOOL DISTRICT  Nevada     NV     03  ...      M
# 9802       CORRECTIONAL SCHOOL DISTRICT  Nevada     NV      N  ...      M
# 9803   CHURCHILL COUNTY SCHOOL DISTRICT  Nevada     NV     03  ...      R
#
#      FL_W01 FL_W31 FL_W61 FL_V95 FL_V02  FL_K14  FL_CE1  FL_CE2  FL_CE3
# 9799      R      R      R      R      R       R       I       I       R
# 9800      R      R      R      R      R       I       R       R       R
# 9801      M      M      M      M      M       M       M       M       M
# 9802      M      M      M      M      M       M       M       M       M
# 9803      R      R      R      R      R       R       R       R       R
#
# [5 rows x 262 columns]

# %% [markdown]
# Read in state level data

# %%
state_grads = pd.read_csv('../../data/state_data_raw/' + file, skiprows=3)

# %%
state_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Group                                   18 non-null     object
#  1   Organization Code                       18 non-null     int64
#  2   Accountability Year                     18 non-null     object
#  3   Graduating Class of                     18 non-null     object
#  4   Total Students                          18 non-null     int64
#  5   Total Graduates                         18 non-null     int64
#  6   Graduation Rate                         18 non-null     float64
#  7   Total Adjusted Diploma                  18 non-null     object
#  8   Total Adult Diploma                     18 non-null     object
#  9   Total Advanced Diploma                  18 non-null     object
#  10  Certificates of Attendance              18 non-null     object
#  11  Total Standard Diploma                  18 non-null     object
#  12  HSE                                     18 non-null     object
#  13  Total Alternative Diploma               0 non-null      float64
#  14  Total College and Career Ready Diploma  0 non-null      float64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 2.2+ KB

# %%
state_grads
# Out:
#                                     Group  Organization Code  \
# 0                             Carson City                 13
# 1                               Churchill                  1
# 2                                   Clark                  2
# 3                                 Douglas                  3
# 4                                    Elko                  4
# 5                                  Eureka                  6
# 6                                Humboldt                  7
# 7                                  Lander                  8
# 8                                 Lincoln                  9
# 9                                    Lyon                 10
# 10                                Mineral                 11
# 11                                    Nye                 12
# 12                               Pershing                 14
# 13  State Public Charter School Authority                 18
# 14                                 Storey                 15
# 15                             University                 19
# 16                                 Washoe                 16
# 17                             White Pine                 17
#
#    Accountability Year Graduating Class of  Total Students  Total Graduates  \
# 0            2018-2019           2017-2018             599              515
# 1            2018-2019           2017-2018             254              193
# 2            2018-2019           2017-2018           24764            21103
# 3            2018-2019           2017-2018             455              403
# 4            2018-2019           2017-2018             685              629
# 5            2018-2019           2017-2018              14               14
# 6            2018-2019           2017-2018             256              232
# 7            2018-2019           2017-2018              76               66
# 8            2018-2019           2017-2018              85               76
# 9            2018-2019           2017-2018             571              484
# 10           2018-2019           2017-2018              28               25
# 11           2018-2019           2017-2018             410              328
# 12           2018-2019           2017-2018              54               52
# 13           2018-2019           2017-2018            1775             1243
# 14           2018-2019           2017-2018              34               32
# 15           2018-2019           2017-2018              27               27
# 16           2018-2019           2017-2018            4716             3980
# 17           2018-2019           2017-2018             163              109
#
#     Graduation Rate Total Adjusted Diploma Total Adult Diploma  \
# 0              86.0                      -                  33
# 1              76.0                      -                   -
# 2              85.2                      -                 334
# 3              88.6                      -                  12
# 4              91.8                      -                   -
# 5             100.0                      -                   -
# 6              90.6                      -                  15
# 7              86.8                      -                   -
# 8              89.4                      -                   -
# 9              84.8                     17                  17
# 10             89.3                      -                   -
# 11             80.0                      -                   -
# 12             96.3                      -                   -
# 13             70.0                      -                   -
# 14             94.1                      -                   -
# 15            100.0                      -                   -
# 16             84.4                     56                   -
# 17             66.9                      -                   -
#
#    Total Advanced Diploma Certificates of Attendance Total Standard Diploma  \
# 0                     179                          -                    303
# 1                      67                          -                    125
# 2                    5767                          -                  15002
# 3                     178                          -                    213
# 4                     219                          -                    410
# 5                       -                          -                      -
# 6                      39                          -                    178
# 7                       -                          -                     59
# 8                      42                          -                     34
# 9                     168                          -                    299
# 10                      -                          -                     19
# 11                     80                          -                    244
# 12                     10                          -                     42
# 13                    363                          -                    880
# 14                     18                          -                     14
# 15                     27                          -                      -
# 16                   1942                          -                   2032
# 17                     24                          -                     84
#
#    HSE  Total Alternative Diploma  Total College and Career Ready Diploma
# 0    -                        NaN                                     NaN
# 1    -                        NaN                                     NaN
# 2    -                        NaN                                     NaN
# 3    -                        NaN                                     NaN
# 4    -                        NaN                                     NaN
# 5    -                        NaN                                     NaN
# 6    -                        NaN                                     NaN
# 7    -                        NaN                                     NaN
# 8    -                        NaN                                     NaN
# 9    -                        NaN                                     NaN
# 10   -                        NaN                                     NaN
# 11   -                        NaN                                     NaN
# 12   -                        NaN                                     NaN
# 13   -                        NaN                                     NaN
# 14   -                        NaN                                     NaN
# 15   -                        NaN                                     NaN
# 16   -                        NaN                                     NaN
# 17   -                        NaN                                     NaN

# %% [markdown]
# Filter results.

# %%
# state_grads = state_grads[(state_grads[''] == '')]

# %% [markdown]
# Select and rename columns.

# %%
state_grads = state_grads[['Group', 'Total Students', 'Graduation Rate']]

# %%
state_grads.columns = ['District Name', 'Total', 'Graduation Rate']

# %%
state_grads
# Out:
#                             District Name  Total  Graduation Rate
# 0                             Carson City    599             86.0
# 1                               Churchill    254             76.0
# 2                                   Clark  24764             85.2
# 3                                 Douglas    455             88.6
# 4                                    Elko    685             91.8
# 5                                  Eureka     14            100.0
# 6                                Humboldt    256             90.6
# 7                                  Lander     76             86.8
# 8                                 Lincoln     85             89.4
# 9                                    Lyon    571             84.8
# 10                                Mineral     28             89.3
# 11                                    Nye    410             80.0
# 12                               Pershing     54             96.3
# 13  State Public Charter School Authority   1775             70.0
# 14                                 Storey     34             94.1
# 15                             University     27            100.0
# 16                                 Washoe   4716             84.4
# 17                             White Pine    163             66.9

# %% [markdown]
# Convert data types.

# %%
state_grads['Total'] = pd.to_numeric(state_grads['Total'])
state_grads['Graduation Rate'] = pd.to_numeric(state_grads['Graduation Rate']) / 100
# Out:
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Check for matches and non-matches in the two lists.

# %%
state_grads['District Name'] = state_grads['District Name'].astype(str).str.upper()
state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.upper()
# Out:
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace('.', '')
state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(',', '')
state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' DISTRICT', '')
state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' DIST', '')
state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' PUBLIC', '')
state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' SCHOOLS', '')
state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' SCHOOL', '')
state_fiscal['NAME'] = state_fiscal['NAME'].astype(str).str.replace(' COUNTY', '')

# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace('.', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(',', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' DISTRICT', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' DIST', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' PUBLIC', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' SCHOOLS', '')
# state_grads['District Name'] = state_grads['District Name'].astype(str).str.replace(' SCHOOL', '')
# Out:
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
matches = [name for name in list(state_grads['District Name']) if name in list(state_fiscal['NAME'])]
matches.sort()
len(matches)
# Out:
# 16

# %%
A = [name for name in list(state_grads['District Name']) if name not in list(state_fiscal['NAME'])]
A.sort()
A
# Out:
# ['STATE PUBLIC CHARTER SCHOOL AUTHORITY', 'UNIVERSITY']

# %%
B = [name for name in list(state_fiscal['NAME']) if name not in list(state_grads['District Name'])]
B.sort()
B
# Out:
# ['ACHIEVEMENT', 'CORRECTIONAL', 'DAVIDSON ACADEMY ', 'STATE-SPONSORED CHARTER']

# %% [markdown]
# Match remaining samples I can find.

# %%
state_fiscal_rename = {'STATE-SPONSORED CHARTER' : 'STATE PUBLIC CHARTER SCHOOL AUTHORITY'}

# %%
state_fiscal = state_fiscal.replace(state_fiscal_rename)

# %% [markdown]
# Merge federal and state data, keeping only matches between the two.

# %%
state_grads_merged = pd.merge(state_fiscal, state_grads, how='inner', left_on='NAME', right_on='District Name')

# %% [markdown]
# Save cleaned data.

# %%
state_grads_merged.to_csv('../../data/state_data_merged/' + abbr + '.csv', index=False)
